# %%
# Install software packages:
# %pip install langchain-openai==0.2.0
# %pip install python-dotenv==1.0.0
# %pip install langchain==0.3.4
# %pip install langchainhub==0.1.13
# %pip install pypdf==3.17.0
# %pip install tiktoken==0.5.1
# %pip install chromadb
# %pip install langchain-community==0.3.20
# %pip install unstructured
# %pip install python-docx
# %pip install unstructured langchain-community
# %pip install selenium
# %pip install "unstructured[all-docs]"
# %pip install gradio
# Out:
# Requirement already satisfied: langchain-openai==0.2.0 in c:\users\gscgo\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-openai==0.2.0) (0.3.58)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-openai==0.2.0) (1.77.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-openai==0.2.0) (0.9.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-openai==0.2.0) (0.1.147)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-openai==0.2.0) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-openai==0.2.0) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-openai==0.2.0) (6.0.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-openai==0.2.0) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-openai==0.2.0) (4.13.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-openai==0.2.0) (2.11.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\gscgo\anaconda3\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\gscgo\anaconda3\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\gscgo\anaconda3\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\gscgo\anaconda3\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (0.9.0)
# Requirement already satisfied: sniffio in c:\users\gscgo\anaconda3\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\gscgo\anaconda3\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (4.66.5)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\gscgo\anaconda3\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai==0.2.0) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in c:\users\gscgo\anaconda3\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai==0.2.0) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\gscgo\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (3.7)
# Requirement already satisfied: certifi in c:\users\gscgo\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\gscgo\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\gscgo\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\gscgo\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain-openai==0.2.0) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\gscgo\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3->langchain-openai==0.2.0) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\gscgo\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3->langchain-openai==0.2.0) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4,>=0.3->langchain-openai==0.2.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4,>=0.3->langchain-openai==0.2.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4,>=0.3->langchain-openai==0.2.0) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gscgo\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai==0.2.0) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gscgo\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai==0.2.0) (2.2.3)
# Requirement already satisfied: colorama in c:\users\gscgo\anaconda3\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dotenv==1.0.0 in c:\users\gscgo\anaconda3\lib\site-packages (1.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain==0.3.4
#   Using cached langchain-0.3.4-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain==0.3.4) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain==0.3.4) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain==0.3.4) (3.10.5)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.12 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain==0.3.4) (0.3.58)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain==0.3.4) (0.3.8)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain==0.3.4) (0.1.147)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain==0.3.4) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain==0.3.4) (2.11.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain==0.3.4) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain==0.3.4) (8.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\gscgo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.4) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\gscgo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.4) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\gscgo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.4) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\gscgo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.4) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\gscgo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.4) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\gscgo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.4) (1.11.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.12->langchain==0.3.4) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.12->langchain==0.3.4) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.12->langchain==0.3.4) (4.13.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\gscgo\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.4) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\gscgo\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.4) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\gscgo\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.4) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.4) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.4) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.4) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gscgo\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.3.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gscgo\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.3.4) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gscgo\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.3.4) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gscgo\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.3.4) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\gscgo\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.3.4) (3.0.1)
# Requirement already satisfied: anyio in c:\users\gscgo\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.4) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\gscgo\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.4) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\gscgo\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.4) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\gscgo\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.4) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\gscgo\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.12->langchain==0.3.4) (2.1)
# Using cached langchain-0.3.4-py3-none-any.whl (1.0 MB)
# Installing collected packages: langchain
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.25
#     Uninstalling langchain-0.3.25:
#       Successfully uninstalled langchain-0.3.25
# Successfully installed langchain-0.3.4
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.3.20 requires langchain<1.0.0,>=0.3.21, but you have langchain 0.3.4 which is incompatible.
# Requirement already satisfied: langchainhub==0.1.13 in c:\users\gscgo\anaconda3\lib\site-packages (0.1.13)
# Requirement already satisfied: requests<3,>=2 in c:\users\gscgo\anaconda3\lib\site-packages (from langchainhub==0.1.13) (2.32.3)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in c:\users\gscgo\anaconda3\lib\site-packages (from langchainhub==0.1.13) (2.32.0.20250328)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gscgo\anaconda3\lib\site-packages (from requests<3,>=2->langchainhub==0.1.13) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gscgo\anaconda3\lib\site-packages (from requests<3,>=2->langchainhub==0.1.13) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gscgo\anaconda3\lib\site-packages (from requests<3,>=2->langchainhub==0.1.13) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gscgo\anaconda3\lib\site-packages (from requests<3,>=2->langchainhub==0.1.13) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# Collecting pypdf==3.17.0
#   Using cached pypdf-3.17.0-py3-none-any.whl.metadata (7.5 kB)
# Using cached pypdf-3.17.0-py3-none-any.whl (277 kB)
# Installing collected packages: pypdf
#   Attempting uninstall: pypdf
#     Found existing installation: pypdf 5.6.0
#     Uninstalling pypdf-5.6.0:
#       Successfully uninstalled pypdf-5.6.0
# Successfully installed pypdf-3.17.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# unstructured-client 0.34.0 requires pypdf>=4.0, but you have pypdf 3.17.0 which is incompatible.
# Collecting tiktoken==0.5.1
#   Using cached tiktoken-0.5.1.tar.gz (32 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: regex>=2022.1.18 in c:\users\gscgo\anaconda3\lib\site-packages (from tiktoken==0.5.1) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in c:\users\gscgo\anaconda3\lib\site-packages (from tiktoken==0.5.1) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gscgo\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken==0.5.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gscgo\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken==0.5.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gscgo\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken==0.5.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gscgo\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken==0.5.1) (2025.1.31)
# Building wheels for collected packages: tiktoken
#   Building wheel for tiktoken (pyproject.toml): started
#   Building wheel for tiktoken (pyproject.toml): finished with status 'error'
# Failed to build tiktoken
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for tiktoken (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [50 lines of output]
#       C:\Users\gscgo\AppData\Local\Temp\pip-build-env-9oiterwn\overlay\Lib\site-packages\setuptools\config\_apply_pyprojecttoml.py:82: SetuptoolsDeprecationWarning: `project.license` as a TOML table is deprecated
#       !!
#
#               ********************************************************************************
#               Please use a simple string containing a SPDX expression for `project.license`. You can also use `project.license-files`. (Both options available on setuptools>=77.0.0).
#
#               By 2026-Feb-18, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         corresp(dist, value, root_dir)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-312\tiktoken
#       copying tiktoken\core.py -> build\lib.win-amd64-cpython-312\tiktoken
#       copying tiktoken\load.py -> build\lib.win-amd64-cpython-312\tiktoken
#       copying tiktoken\model.py -> build\lib.win-amd64-cpython-312\tiktoken
#       copying tiktoken\registry.py -> build\lib.win-amd64-cpython-312\tiktoken
#       copying tiktoken\_educational.py -> build\lib.win-amd64-cpython-312\tiktoken
#       copying tiktoken\__init__.py -> build\lib.win-amd64-cpython-312\tiktoken
#       creating build\lib.win-amd64-cpython-312\tiktoken_ext
#       copying tiktoken_ext\openai_public.py -> build\lib.win-amd64-cpython-312\tiktoken_ext
#       running egg_info
#       writing tiktoken.egg-info\PKG-INFO
#       writing dependency_links to tiktoken.egg-info\dependency_links.txt
#       writing requirements to tiktoken.egg-info\requires.txt
#       writing top-level names to tiktoken.egg-info\top_level.txt
#       reading manifest file 'tiktoken.egg-info\SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching 'Makefile'
#       adding license file 'LICENSE'
#       writing manifest file 'tiktoken.egg-info\SOURCES.txt'
#       copying tiktoken\py.typed -> build\lib.win-amd64-cpython-312\tiktoken
#       running build_ext
#       running build_rust
#       error: can't find Rust compiler
#
#       If you are using an outdated pip version, it is possible a prebuilt wheel is available for this package but pip is not able to install from it. Installing from the wheel would avoid the need for a Rust compiler.
#
#       To update pip, run:
#
#           pip install --upgrade pip
#
#       and then retry package installation.
#
#       If you did intend to build this package from source, try installing a Rust compiler from your system package manager and ensure it is on the PATH during installation. Alternatively, rustup (available at https://rustup.rs) is the recommended way to download and update the Rust compiler toolchain.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tiktoken
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (tiktoken)
# Requirement already satisfied: chromadb in c:\users\gscgo\anaconda3\lib\site-packages (1.0.9)
# Requirement already satisfied: build>=1.0.3 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (2.11.4)
# Requirement already satisfied: fastapi==0.115.9 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (0.115.9)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\gscgo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.2)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (4.0.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (4.13.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (13.7.1)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\gscgo\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in c:\users\gscgo\anaconda3\lib\site-packages (from fastapi==0.115.9->chromadb) (0.45.3)
# Requirement already satisfied: packaging>=19.1 in c:\users\gscgo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Requirement already satisfied: pyproject_hooks in c:\users\gscgo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\gscgo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\gscgo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.2.0)
# Requirement already satisfied: certifi in c:\users\gscgo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\gscgo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: idna in c:\users\gscgo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: sniffio in c:\users\gscgo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\gscgo\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\gscgo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\gscgo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\gscgo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\gscgo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.10.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\gscgo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\gscgo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\gscgo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.40.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\gscgo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\gscgo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in c:\users\gscgo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\gscgo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\gscgo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\gscgo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: coloredlogs in c:\users\gscgo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\gscgo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\gscgo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: sympy in c:\users\gscgo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\gscgo\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in c:\users\gscgo\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\gscgo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in c:\users\gscgo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in c:\users\gscgo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b1 in c:\users\gscgo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b1 in c:\users\gscgo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in c:\users\gscgo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-util-http==0.54b1 in c:\users\gscgo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\gscgo\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\gscgo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\gscgo\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\gscgo\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\gscgo\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gscgo\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\gscgo\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.31.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\gscgo\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\gscgo\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\gscgo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\gscgo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\gscgo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in c:\users\gscgo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\gscgo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\gscgo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\gscgo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: filelock in c:\users\gscgo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\gscgo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\gscgo\anaconda3\lib\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gscgo\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gscgo\anaconda3\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.3.2)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\gscgo\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\gscgo\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\gscgo\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\gscgo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain-community==0.3.20 in c:\users\gscgo\anaconda3\lib\site-packages (0.3.20)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-community==0.3.20) (0.3.58)
# Collecting langchain<1.0.0,>=0.3.21 (from langchain-community==0.3.20)
#   Using cached langchain-0.3.25-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-community==0.3.20) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-community==0.3.20) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-community==0.3.20) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-community==0.3.20) (3.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-community==0.3.20) (8.2.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-community==0.3.20) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-community==0.3.20) (2.6.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-community==0.3.20) (0.1.147)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-community==0.3.20) (0.4.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-community==0.3.20) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\gscgo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.20) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\gscgo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.20) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\gscgo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.20) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\gscgo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.20) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\gscgo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.20) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\gscgo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.20) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\gscgo\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.20) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\gscgo\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.20) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain<1.0.0,>=0.3.21->langchain-community==0.3.20) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain<1.0.0,>=0.3.21->langchain-community==0.3.20) (2.11.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain-community==0.3.20) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain-community==0.3.20) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\gscgo\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain-community==0.3.20) (4.13.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\gscgo\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community==0.3.20) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\gscgo\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community==0.3.20) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\gscgo\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community==0.3.20) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community==0.3.20) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gscgo\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.3.20) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gscgo\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.3.20) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gscgo\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.3.20) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gscgo\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.3.20) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\gscgo\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community==0.3.20) (3.0.1)
# Requirement already satisfied: anyio in c:\users\gscgo\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community==0.3.20) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\gscgo\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community==0.3.20) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\gscgo\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community==0.3.20) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\gscgo\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community==0.3.20) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\gscgo\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain-community==0.3.20) (2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.21->langchain-community==0.3.20) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.21->langchain-community==0.3.20) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.21->langchain-community==0.3.20) (0.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\gscgo\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.20) (1.0.0)
# Using cached langchain-0.3.25-py3-none-any.whl (1.0 MB)
# Installing collected packages: langchain
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.4
#     Uninstalling langchain-0.3.4:
#       Successfully uninstalled langchain-0.3.4
# Successfully installed langchain-0.3.25
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: unstructured in c:\users\gscgo\anaconda3\lib\site-packages (0.17.2)
# Requirement already satisfied: chardet in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (4.0.0)
# Requirement already satisfied: filetype in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (5.2.1)
# Requirement already satisfied: nltk in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: requests in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (4.12.3)
# Requirement already satisfied: emoji in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (2.14.1)
# Requirement already satisfied: dataclasses-json in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (2025.2.18)
# Requirement already satisfied: langdetect in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (1.26.4)
# Requirement already satisfied: rapidfuzz in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (3.13.0)
# Requirement already satisfied: backoff in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (4.13.2)
# Requirement already satisfied: unstructured-client in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (0.34.0)
# Requirement already satisfied: wrapt in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (1.14.1)
# Requirement already satisfied: tqdm in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (4.66.5)
# Requirement already satisfied: psutil in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (5.9.0)
# Requirement already satisfied: python-oxmsg in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: html5lib in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\gscgo\anaconda3\lib\site-packages (from beautifulsoup4->unstructured) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\gscgo\anaconda3\lib\site-packages (from dataclasses-json->unstructured) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\gscgo\anaconda3\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six>=1.9 in c:\users\gscgo\anaconda3\lib\site-packages (from html5lib->unstructured) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\gscgo\anaconda3\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in c:\users\gscgo\anaconda3\lib\site-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in c:\users\gscgo\anaconda3\lib\site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\gscgo\anaconda3\lib\site-packages (from nltk->unstructured) (2024.9.11)
# Requirement already satisfied: olefile in c:\users\gscgo\anaconda3\lib\site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gscgo\anaconda3\lib\site-packages (from requests->unstructured) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gscgo\anaconda3\lib\site-packages (from requests->unstructured) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gscgo\anaconda3\lib\site-packages (from requests->unstructured) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gscgo\anaconda3\lib\site-packages (from requests->unstructured) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\gscgo\anaconda3\lib\site-packages (from tqdm->unstructured) (0.4.6)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured-client->unstructured) (24.1.0)
# Requirement already satisfied: cryptography>=3.1 in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured-client->unstructured) (43.0.0)
# Requirement already satisfied: eval-type-backport>=0.2.0 in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured-client->unstructured) (0.2.2)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured-client->unstructured) (0.27.0)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: pydantic>=2.11.2 in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured-client->unstructured) (2.11.4)
# Collecting pypdf>=4.0 (from unstructured-client->unstructured)
#   Using cached pypdf-5.6.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured-client->unstructured) (0.4.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\gscgo\anaconda3\lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: anyio in c:\users\gscgo\anaconda3\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\gscgo\anaconda3\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\gscgo\anaconda3\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\gscgo\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\gscgo\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (2.33.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\gscgo\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: pycparser in c:\users\gscgo\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.21)
# Using cached pypdf-5.6.0-py3-none-any.whl (304 kB)
# Installing collected packages: pypdf
#   Attempting uninstall: pypdf
#     Found existing installation: pypdf 3.17.0
#     Uninstalling pypdf-3.17.0:
#       Successfully uninstalled pypdf-3.17.0
# Successfully installed pypdf-5.6.0
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-docx in c:\users\gscgo\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\gscgo\anaconda3\lib\site-packages (from python-docx) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\gscgo\anaconda3\lib\site-packages (from python-docx) (4.13.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: unstructured in c:\users\gscgo\anaconda3\lib\site-packages (0.17.2)
# Requirement already satisfied: langchain-community in c:\users\gscgo\anaconda3\lib\site-packages (0.3.20)
# Requirement already satisfied: chardet in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (4.0.0)
# Requirement already satisfied: filetype in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (5.2.1)
# Requirement already satisfied: nltk in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: requests in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured) (4.12.3)
# ...
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gscgo\anaconda3\lib\site-packages (from pandas->unstructured[all-docs]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gscgo\anaconda3\lib\site-packages (from pandas->unstructured[all-docs]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gscgo\anaconda3\lib\site-packages (from pandas->unstructured[all-docs]) (2023.3)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\gscgo\anaconda3\lib\site-packages (from pdfminer.six->unstructured[all-docs]) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\gscgo\anaconda3\lib\site-packages (from pdfminer.six->unstructured[all-docs]) (43.0.0)
# Requirement already satisfied: Deprecated in c:\users\gscgo\anaconda3\lib\site-packages (from pikepdf->unstructured[all-docs]) (1.2.18)
# Requirement already satisfied: olefile in c:\users\gscgo\anaconda3\lib\site-packages (from python-oxmsg->unstructured[all-docs]) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gscgo\anaconda3\lib\site-packages (from requests->unstructured[all-docs]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gscgo\anaconda3\lib\site-packages (from requests->unstructured[all-docs]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gscgo\anaconda3\lib\site-packages (from requests->unstructured[all-docs]) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\gscgo\anaconda3\lib\site-packages (from tqdm->unstructured[all-docs]) (0.4.6)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured-client->unstructured[all-docs]) (24.1.0)
# Requirement already satisfied: eval-type-backport>=0.2.0 in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured-client->unstructured[all-docs]) (0.2.2)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured-client->unstructured[all-docs]) (0.27.0)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured-client->unstructured[all-docs]) (1.6.0)
# Requirement already satisfied: pydantic>=2.11.2 in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured-client->unstructured[all-docs]) (2.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured-client->unstructured[all-docs]) (1.0.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\gscgo\anaconda3\lib\site-packages (from unstructured-client->unstructured[all-docs]) (0.4.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\gscgo\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (1.17.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\gscgo\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.70.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\gscgo\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\gscgo\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\gscgo\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\gscgo\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\gscgo\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (4.9.1)
# Requirement already satisfied: anyio in c:\users\gscgo\anaconda3\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured[all-docs]) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\gscgo\anaconda3\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured[all-docs]) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\gscgo\anaconda3\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured[all-docs]) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\gscgo\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured[all-docs]) (0.14.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\gscgo\anaconda3\lib\site-packages (from omegaconf>=2.0->effdet->unstructured[all-docs]) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in c:\users\gscgo\anaconda3\lib\site-packages (from omegaconf>=2.0->effdet->unstructured[all-docs]) (6.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gscgo\anaconda3\lib\site-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[all-docs]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gscgo\anaconda3\lib\site-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[all-docs]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gscgo\anaconda3\lib\site-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[all-docs]) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gscgo\anaconda3\lib\site-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[all-docs]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gscgo\anaconda3\lib\site-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[all-docs]) (3.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured[all-docs]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured[all-docs]) (2.33.2)
# Requirement already satisfied: safetensors in c:\users\gscgo\anaconda3\lib\site-packages (from timm->unstructured-inference>=0.8.10->unstructured[all-docs]) (0.5.3)
# Requirement already satisfied: filelock in c:\users\gscgo\anaconda3\lib\site-packages (from torch->unstructured-inference>=0.8.10->unstructured[all-docs]) (3.13.1)
# Requirement already satisfied: jinja2 in c:\users\gscgo\anaconda3\lib\site-packages (from torch->unstructured-inference>=0.8.10->unstructured[all-docs]) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\gscgo\anaconda3\lib\site-packages (from torch->unstructured-inference>=0.8.10->unstructured[all-docs]) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\gscgo\anaconda3\lib\site-packages (from torch->unstructured-inference>=0.8.10->unstructured[all-docs]) (75.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\gscgo\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.19.0->unstructured[all-docs]) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\gscgo\anaconda3\lib\site-packages (from transformers>=4.25.1->unstructured-inference>=0.8.10->unstructured[all-docs]) (0.21.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\gscgo\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured[all-docs]) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\gscgo\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.19.0->unstructured[all-docs]) (10.0)
# Requirement already satisfied: pycparser in c:\users\gscgo\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (2.21)
# Requirement already satisfied: pyreadline3 in c:\users\gscgo\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.19.0->unstructured[all-docs]) (3.5.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\gscgo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (0.4.8)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gscgo\anaconda3\lib\site-packages (from jinja2->torch->unstructured-inference>=0.8.10->unstructured[all-docs]) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gradio in c:\users\gscgo\anaconda3\lib\site-packages (5.32.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (4.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (0.115.9)
# Requirement already satisfied: ffmpy in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.10.2 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (1.10.2)
# Requirement already satisfied: groovy~=0.1 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.28.1 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (0.31.2)
# Requirement already satisfied: jinja2<4.0 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (3.10.18)
# Requirement already satisfied: packaging in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (2.11.4)
# Requirement already satisfied: pydub in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (0.11.12)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (0.45.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (0.16.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (4.13.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio) (0.34.2)
# Requirement already satisfied: fsspec in c:\users\gscgo\anaconda3\lib\site-packages (from gradio-client==1.10.2->gradio) (2024.6.1)
# Requirement already satisfied: websockets<16.0,>=10.0 in c:\users\gscgo\anaconda3\lib\site-packages (from gradio-client==1.10.2->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\gscgo\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\gscgo\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: certifi in c:\users\gscgo\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\gscgo\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\gscgo\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\gscgo\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (3.13.1)
# Requirement already satisfied: requests in c:\users\gscgo\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\gscgo\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gscgo\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gscgo\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gscgo\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\gscgo\anaconda3\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.4.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\gscgo\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\gscgo\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\gscgo\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: colorama in c:\users\gscgo\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\gscgo\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\gscgo\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gscgo\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gscgo\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gscgo\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.2.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gscgo\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
from langchain_openai import AzureChatOpenAI, AzureOpenAIEmbeddings

os.environ["ALLOW_RESET"] = "TRUE"

load_dotenv('.env', override=True)

# # Explicitly set the deployment name to match your Azure deployment
embedding_model = AzureOpenAIEmbeddings(
    model=os.getenv('AZURE_OPENAI_EMBEDDING_DEPLOYMENT'),
    azure_endpoint=os.getenv('AZURE_OPENAI_EMBEDDING_ENDPOINT'),
    api_version=os.getenv('AZURE_OPENAI_EMBEDDING_API_VERSION'),
    api_key=os.getenv('AZURE_OPENAI_EMBEDDING_API_KEY')
    )

# Instantiate an AzureOpenAI LLM:
llm = AzureChatOpenAI(
    azure_deployment=os.getenv("AZURE_OPENAI_CHAT_DEPLOYMENT_NAME"),
    api_version=os.getenv("AZURE_OPENAI_API_VERSION"),
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %%
#load web page from MOM PWM URLS:
from langchain_openai import AzureChatOpenAI, AzureOpenAIEmbeddings
# ========== UPDATED IMPORTS (FIX FOR LANGCHAIN DEPRECATION) ==========
# CHANGE: Updated to use langchain_community for deprecated imports
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import UnstructuredWordDocumentLoader
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.document_loaders import PyPDFDirectoryLoader
from langchain_community.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains import RetrievalQA

from langchain.document_loaders import WebBaseLoader
loader_multiple_pages = WebBaseLoader(["https://www.mom.gov.sg/employment-practices/progressive-wage-model/cleaning-sector",
                                      "https://www.mom.gov.sg/employment-practices/progressive-wage-model/retail-sector",
                                      "https://www.mom.gov.sg/employment-practices/progressive-wage-model/food-services-sector",
                                      "https://www.mom.gov.sg/employment-practices/progressive-wage-model/occupational-pws-for-administrators-and-drivers",
                                      "https://www.mom.gov.sg/employment-practices/leave/shared-parental-leave"
                                      "https://sso.agc.gov.sg/act/ema1968"
                                      "https://sso.agc.gov.sg/Act/CDCSA2001"
                                      "https://sso.agc.gov.sg/Act/IRA1960"
                                      "https://www.mom.gov.sg/-/media/mom/documents/employment-practices/guidelines/tripartite-advisory-on-managing-excess-manpower-and-responsible-retrenchment.pdf"
                                      ])



web_documents = loader_multiple_pages.load()

# %%
#load CAs in docx format
from langchain.document_loaders import DirectoryLoader
from langchain.document_loaders import UnstructuredWordDocumentLoader

folder_path="./wst"
txt_loader = DirectoryLoader(folder_path, glob="*.docx", loader_cls=UnstructuredWordDocumentLoader)
txt_documents = txt_loader.load()

# %%
# Import a splitter module called RecursiveCharacterTextSplitter:
from langchain.text_splitter import RecursiveCharacterTextSplitter
# Instantiate the splitter:
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=0)
# Do the splitting:
splits = text_splitter.split_documents(loader.load())

# Embed and store splits in Chroma database.
# Import the Chroma and embeddings modules:
from langchain.vectorstores import Chroma
# from langchain.embeddings import OpenAIEmbeddings
# Instantiate the Chroma vector store with arguments:

# Comment out the following lines to process in smaller batches with delay to avoid hitting the rate limit when creating the embeddings:
# vectorstore = Chroma.from_documents(
#     documents=splits,
#     embedding=embedding_model
# )


import time
from tqdm import tqdm

# Create an empty Chroma DB first
vectorstore = Chroma(
    embedding_function=embedding_model
)

# Process in smaller batches
batch_size = 10
for i in tqdm(range(0, len(splits), batch_size)):
    batch = splits[i:i+batch_size]
    try:
        vectorstore.add_documents(documents=batch)
    except Exception as e:
        print(f"Error on batch {i}-{i+batch_size}: {e}")
        # Wait before retrying
        time.sleep(60)
        vectorstore.add_documents(documents=batch)
    # Small delay between successful batches
    time.sleep(2)

# Instantiate a retriever based on the vector store:
retriever = vectorstore.as_retriever()
# Out:
# 100%|██████████| 16/16 [00:07<00:00,  2.26it/s]
# 100%|██████████| 196/196 [09:18<00:00,  2.85s/it]

# %%
# ========== MINOR MODIFICATION FOR UI ==========
# Set up a retrieval chain:
# CHANGE 2: Kept return_source_documents=True to show source citations in UI
qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectorstore.as_retriever(
        search_type="mmr",
        search_kwargs={"k": 5}
    ),
    return_source_documents=True  # Essential for source citations in web UI
)

# ========== MAJOR CHANGE: REPLACED HARDCODED EXECUTION WITH INTERACTIVE FUNCTION ==========
# ORIGINAL CODE REMOVED:
# query = "In the event that retrenchment is inevitable, what should companies do?"
# completion = qa.invoke({"query": query})
# print(completion['result'])

# CHANGE 3: Created interactive function to handle user questions
def ask_question(question):
    """
    Function to process user questions and return answers with sources
    
    CHANGES MADE FOR GRADIO UI:
    - Takes user input instead of hard-coded query
    - Validates input (checks for empty questions)  
    - Formats response with source citations for better web display
    - Includes error handling for robust UI experience
    - Returns formatted string suitable for Gradio text display
    """
    if not question.strip():
        return "Please enter a question."
    
    try:
        # Run the retrieval chain and get a response from the LLM
        completion = qa.invoke({"query": question})
        
        # Format the response with sources
        answer = completion['result']
        sources = completion.get('source_documents', [])
        
        # NEW FEATURE: Add source citations to answer (not in original script)
        if sources:
            source_info = "\n\n**Sources:**\n"
            for i, doc in enumerate(sources[:3], 1):  # Show top 3 sources
                source_info += f"{i}. {doc.metadata.get('source', 'Unknown source')}\n"
            answer += source_info
        
        return answer
    except Exception as e:
        return f"An error occurred: {str(e)}"

# %%
# ========== CHANGE 4: COMPLETE GRADIO WEB INTERFACE (ENTIRELY NEW) ==========
# This entire section replaces the simple print statement with a full web UI
# CHANGE 1: Added Gradio import to enable web-based user interface. Remember to pip install gradio in the terminal within the virtual/conda environment before running the script.
import gradio as gr

import time
from tqdm import tqdm

os.environ["ALLOW_RESET"] = "TRUE"

load_dotenv('.env', override=True)
with gr.Blocks(title="Collective Agreement Virtual Assistant") as app:
    # Professional header with description
    gr.Markdown(
        """
        # 🤖 Collective Agreement Virtual Assistant
        
        Ask questions about collective agreements, salary ranges, and progressive wage models.
        The assistant draws information from existing legislations, tripartite guidelines, Collective Agreeement (CA) documents, and MOM resources.
        """
    )
        
    # Two-column layout for clean interface
    with gr.Row():
        with gr.Column():
            # Question input area with helpful placeholder
            question_input = gr.Textbox(
                label="Your Question",
                placeholder="e.g., What is the salary of drivers across food manufacturing CAs?",
                lines=3
            )
            # Primary submit button
            submit_btn = gr.Button("Ask Question", variant="primary")
            
        with gr.Column():
            # Answer display area with appropriate sizing
            answer_output = gr.Textbox(
                label="Answer",
                lines=15,
                max_lines=20
            )
    
    # Example questions to guide users
    gr.Examples(
        examples=[
            ["What is the salary ranges for drivers across food manufactuirng CAs?"],
            ["What is the current progressive wage model wage requirements for restroom cleaners?"],
            ["What is the salary ranges for housekeepers across hotels CAs?"],
            ["What is the current entitlement for shared parental leave?"],
            ["What is the current entitlement for childcare leave?"],
        ],
        inputs=question_input
    )
    
    # Connect the interactive function to UI elements
    # Two ways to submit questions for better user experience
    submit_btn.click(
        fn=ask_question,
        inputs=question_input,
        outputs=answer_output
    )
    
    # Allow Enter key submission
    question_input.submit(
        fn=ask_question,
        inputs=question_input,
        outputs=answer_output
    )

#PROMPT TEMPLATE
from langchain.schema.runnable import RunnablePassthrough
from langchain import hub
from langchain_core.prompts import PromptTemplate
template = """
You are a virtual assistant for Industrial Relations Officers in Food, Drinks and Allied Workers Union who have to benchmark Employees Agreement to draft Agreements for negotiations with unionised companies in Singapore.
For prompts relating to Progressive Wage Model or Occupational Progressive Wages, refer to the webpages loaded. For these prompts, to also include if the wage requirements refers monthly basic or gross wages.
Prompts with the word "PWM" refers to the Progressive Wage Model, while prompts with the word "OPW" refers to Occupational Progressive Wages. For these prompts, refer to the Ministry of Manpower webpages loaded for progressive wage models and occupational progressive wage.For these prompts, to also include if the wage requirements refers to monthly basic or gross wages.
For prompts on PWM wage requirements for cleaners or housekeepers, refer to the loaded webpage from MOM on Progressive Wage Model for Cleaning Sector: https://www.mom.gov.sg/employment-practices/progressive-wage-model/cleaning-sector
For prompts on OPW or PWM wage requirements for drivers, refer to the loaded webpage from MOM on Occupational Progressive Wages for administrators and drivers:https://www.mom.gov.sg/employment-practices/progressive-wage-model/occupational-pws-for-administrators-and-drivers
For prompts on PWM wage requirements for cooks or waiters, refer to the loaded webpage from MOM on Progressive Wage Model for Food Services Sector:https://www.mom.gov.sg/employment-practices/progressive-wage-model/food-services-sector
For prompts on OPW or PWM wage requirements for admin assistant, admin executive, concierge or storekeeper, refer to the loaded webpage from MOM on Occupational Progressive Wages for adminstrator and drivers:https://www.mom.gov.sg/employment-practices/progressive-wage-model/occupational-pws-for-administrators-and-drivers
For prompts on PWM wage requirements for cashier or retail assistant, refer to the loaded webpage from MOM on Progressive Wage Model for Retail Sector:https://www.mom.gov.sg/employment-practices/progressive-wage-model/retail-sector
For prompts relating to 'Collective Agreements' or 'CAs', it refers to the Employees Agreements loaded. The names of the companies can be found in the first page of the Employees Agreement.
For prompts relating to shared parental leave, paternity leave, childcare leave and maternity leave, refer to the webpage loaded from Child Development Co-Savings Act here:https://sso.agc.gov.sg/Act/CDCSA2001 .
For prompts relating to employment rights such as rest day pay and entitlements, refer to the webpage loaded on employment act: https://sso.agc.gov.sg/act/ema1968
For prompts relating to tripartite guidelines on retrenchments, refer to the MOM webpage loaded for tripartite guidelines on managing excess manpower and responsible retrenchment:https://www.mom.gov.sg/-/media/mom/documents/employment-practices/guidelines/tripartite-advisory-on-managing-excess-manpower-and-responsible-retrenchment.pdf .
For prompts requesting to list salary ranges of a specific job position across an industry (for example, hospitality/hotels and food manufacturing), refer to Employees Agreement of companies in those industries. List all the relevant job positions and indicate which company each salary ranges belongs to.
For prompts requesting to list salary ranges in Hotel CAs, it refers to Collective Agreeements from hotels, such as Conrad Centennial, Four Seasons, Grand Copthorne Waterfront, Grand Hyatt Singapore, Hotel Royal, Parkroyal Beach Rd, Raffles Hotel, RC Hotels, Ritz Carlton and Shangri-La Hotel. Common job positions in hotel CAs include housekeepers, concierge, bellman, F&B captain, waitress, engineering technician, chef and front office. Indicate which documents that the specific salary ranges are extracted from.
For prompts requesting to list salary ranges in Food Manufacturing CAs, it refers to Collective Agreements from food manufacturing companies, such as Asia Pacific Breweries, Lam Soon, Meiji Seika, Mondelez, Olam Cocoa, YHS. Common job positions in food manufacturing CAs include storekeepers, operators, technicians, merchandiser, clerk, general worker, production supervisor and forklift driver. Indicate which documents that the specific salary ranges are extracted from.
For outputs on salary ranges, indicate the company together with the respective salary ranges in the same line.
Be as detailed as possible with your responses.


{context}

Question: {question}
Helpful Answer:"""
custom_rag_prompt = PromptTemplate.from_template(template)

# Instantiate RAG chain:
custom_rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | custom_rag_prompt
    | llm
)

# ========== CHANGE 5: LAUNCH WEB INTERFACE INSTEAD OF ONE-TIME EXECUTION ==========
# REPLACED: Single execution with print output
# NEW: Persistent web server that stays active for continuous use
if __name__ == "__main__":
    # share=True creates a public shareable link
    # Server runs continuously until stopped
    app.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7894
# * Running on public URL: https://0cec72b595d942b1e0.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://0cec72b595d942b1e0.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
